# %%
import pandas as pd

# %% [markdown]
# 加载数据，查看基本信息

# %%
df = pd.read_csv('data/employees.csv')

# %%
print(df)
# Out:
#      employee_id first_name last_name     email  phone_number      job_id  \
# 0            100     Steven      King     SKING  515.123.4567     AD_PRES
# 1            101      N_ann   Kochhar  NKOCHHAR  515.123.4568       AD_VP
# 2            102        Lex   De Haan   LDEHAAN  515.123.4569       AD_VP
# 3            103  Alexander    Hunold   AHUNOLD  590.423.4567     IT_PROG
# 4            104      Bruce     Ernst    BERNST  590.423.4568     IT_PROG
# ..           ...        ...       ...       ...           ...         ...
# 102          202        Pat       Fay      PFAY  603.123.6666      MK_REP
# 103          203      Susan    Mavris   SMAVRIS  515.123.7777      HR_REP
# 104          204    Hermann      Baer     HBAER  515.123.8888      PR_REP
# 105          205    Shelley   Higgins  SHIGGINS  515.123.8080      AC_MGR
# 106          206    William     Gietz    WGIETZ  515.123.8181  AC_ACCOUNT
#
#       salary  commission_pct  manager_id  department_id
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 107 entries, 0 to 106
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   employee_id     107 non-null    int64
#  1   first_name      107 non-null    str
#  2   last_name       107 non-null    str
#  3   email           107 non-null    str
#  4   phone_number    107 non-null    str
#  5   job_id          107 non-null    str
#  6   salary          107 non-null    float64
#  7   commission_pct  35 non-null     float64
#  8   manager_id      106 non-null    float64
#  9   department_id   106 non-null    float64
# dtypes: float64(4), int64(1), str(5)
# memory usage: 8.5 KB
# None

# %%
print(df.describe())
# Out:
#        employee_id        salary  commission_pct  manager_id  department_id
# count   107.000000    107.000000       35.000000  106.000000     106.000000
# mean    153.000000   6461.682243        0.222857  124.764151      63.207547
# std      31.032241   3909.365746        0.085184   20.315395      20.910110
# min     100.000000   2100.000000        0.100000  100.000000      10.000000
# 25%     126.500000   3100.000000        0.150000  108.000000      50.000000
# 50%     153.000000   6200.000000        0.200000  122.000000      50.000000
# 75%     179.500000   8900.000000        0.300000  145.000000      80.000000
# max     206.000000  24000.000000        0.400000  205.000000     110.000000

# %%
print(df.head())
# Out:
#    employee_id first_name last_name     email  phone_number   job_id   salary  \
# 0          100     Steven      King     SKING  515.123.4567  AD_PRES  24000.0
# 1          101      N_ann   Kochhar  NKOCHHAR  515.123.4568    AD_VP  17000.0
# 2          102        Lex   De Haan   LDEHAAN  515.123.4569    AD_VP  17000.0
# 3          103  Alexander    Hunold   AHUNOLD  590.423.4567  IT_PROG   9000.0
# 4          104      Bruce     Ernst    BERNST  590.423.4568  IT_PROG   6000.0
#
#    commission_pct  manager_id  department_id
# 0             NaN         NaN           90.0
# 1             NaN       100.0           90.0
# 2             NaN       100.0           90.0
# 3             NaN       102.0           60.0
# 4             NaN       103.0           60.0

# %%
print(df.shape)
# Out:
# (107, 10)

# %% [markdown]
# 找出薪资最低、最高的员工

# %%
df['salary']==df['salary'].max()
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 102    False
# 103    False
# 104    False
# 105    False
# 106    False
# Name: salary, Length: 107, dtype: bool

# %%
df[df['salary']==df['salary'].max()]
# Out:
#    employee_id first_name last_name  email  phone_number   job_id   salary  \
# 0          100     Steven      King  SKING  515.123.4567  AD_PRES  24000.0
#
#    commission_pct  manager_id  department_id
# 0             NaN         NaN           90.0

# %%
df[df['salary']==df['salary'].min()]
# Out:
#     employee_id first_name last_name    email  phone_number    job_id  salary  \
# 32          132         TJ     Olson  TJOLSON  650.124.8234  ST_CLERK  2100.0
#
#     commission_pct  manager_id  department_id
# 32             NaN       121.0           50.0

# %%
df.loc[df["salary"]== df["salary"].min()]
# Out:
#     employee_id first_name last_name    email  phone_number    job_id  salary  \
# 32          132         TJ     Olson  TJOLSON  650.124.8234  ST_CLERK  2100.0
#
#     commission_pct  manager_id  department_id
# 32             NaN       121.0           50.0

# %% [markdown]
# 找出薪资最高的10名员工

# %%
df.sort_values(by=['salary'], ascending=False).head(10)[['employee_id','salary']]
# Out:
#      employee_id   salary
# 0            100  24000.0
# 1            101  17000.0
# 2            102  17000.0
# 45           145  14000.0
# 46           146  13500.0
# 101          201  13000.0
# 8            108  12000.0
# 47           147  12000.0
# 105          205  12000.0
# 68           168  11500.0

# %%
print(df.nlargest(10, "salary"))
# Out:
#      employee_id first_name  last_name     email        phone_number   job_id  \
# 0            100     Steven       King     SKING        515.123.4567  AD_PRES
# 1            101      N_ann    Kochhar  NKOCHHAR        515.123.4568    AD_VP
# 2            102        Lex    De Haan   LDEHAAN        515.123.4569    AD_VP
# 45           145       John    Russell   JRUSSEL  011.44.1344.429268   SA_MAN
# 46           146      Karen   Partners  KPARTNER  011.44.1344.467268   SA_MAN
# 101          201    Michael  Hartstein  MHARTSTE        515.123.5555   MK_MAN
# 8            108      Nancy  Greenberg  NGREENBE        515.124.4569   FI_MGR
# 47           147    Alberto  Errazuriz  AERRAZUR  011.44.1344.429278   SA_MAN
# 105          205    Shelley    Higgins  SHIGGINS        515.123.8080   AC_MGR
# 68           168       Lisa       Ozer     LOZER  011.44.1343.929268   SA_REP
#
#       salary  commission_pct  manager_id  department_id
# ...

# %% [markdown]
# 查看所有部门id

# %%
df.groupby('department_id')['department_id'].unique()
# Out:
# department_id
# 10.0      [10.0]
# 20.0      [20.0]
# 30.0      [30.0]
# 40.0      [40.0]
# 50.0      [50.0]
# 60.0      [60.0]
# 70.0      [70.0]
# 80.0      [80.0]
# 90.0      [90.0]
# 100.0    [100.0]
# 110.0    [110.0]
# Name: department_id, dtype: object

# %% [markdown]
# department_ids = df.groupby('department_id')['department_id'].unique()

# %%
df.groupby('department_id')['employee_id'].count().rename('employee_count')
# Out:
# department_id
# 10.0      1
# 20.0      2
# 30.0      6
# 40.0      1
# 50.0     45
# 60.0      5
# 70.0      1
# 80.0     34
# 90.0      3
# 100.0     6
# 110.0     2
# Name: employee_count, dtype: int64

# %% [markdown]
# 绘制每个部门员工数的bar图·

# %%
df_ = df.groupby('department_id')['employee_id'].agg(['count']).plot(kind='bar')

# %% [markdown]
# 找出平均薪资最高的部门id

# %%
df.groupby('department_id')['salary'].mean().nlargest(1)
# Out:
# department_id
# 90.0    19333.333333
# Name: salary, dtype: float64
