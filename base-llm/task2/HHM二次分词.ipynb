# %%
import jieba

# %% [markdown]
# 由单字组成的“未登录区域”结束时，`jieba` 会调用 HMM 模型对缓冲区里的字符串进行**二次分词**

# %%
text = '力工梭哈'

# %%
seg_list = jieba.lcut(text, HMM=False)
seg_list
# Out:
# ['力', '工', '梭哈']

# %%
seg_list = jieba.lcut(text, HMM=True) # HMM默认为True
seg_list
# Out:
# ['力工', '梭哈']
